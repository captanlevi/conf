# %%
from influxdb_client import InfluxDBClient, BucketsApi
influx_token = "kQoO1Dyu-iB7ZC8vAQKXD1U7hNdNpZGBE3DdAMyLZK_t0UFm2IzuaNnw9B8hVbDv3N9TNth_xxfJhbszwH5mIg=="
import pandas as pd

# %%
client = InfluxDBClient(url="http://localhost:8086", token= influx_token, org="shadow_force")

# %%
buckets_api = client.buckets_api()

# %%
buckets_api.create_bucket(bucket_name="zoom", org="shadow_force", retention_rules=[])
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 buckets_api.create_bucket(bucket_name="zoom", org="shadow_force", retention_rules=[])
#
# File /usr/local/lib/python3.11/site-packages/influxdb_client/client/bucket_api.py:56, in BucketsApi.create_bucket(self, bucket, bucket_name, org_id, retention_rules, description, org)
#      50     warnings.warn("org_id is deprecated; use org", DeprecationWarning)
#      52 if bucket is None:
#      53     bucket = PostBucketRequest(name=bucket_name,
#      54                                retention_rules=rules,
#      55                                description=description,
# ---> 56                                org_id=get_org_query_param(org=(org_id if org is None else org),
#      57                                                           client=self._influxdb_client,
# ...
